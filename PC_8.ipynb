# %% [markdown]
# <a href="https://colab.research.google.com/github/SonnxDev/QUIMICASM/blob/main/PC_8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# !pip install drawdata
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 23.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 121.9/121.9 kB 19.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 93.4/93.4 kB 14.3 MB/s eta 0:00:00
# ...

# %% [markdown]
# --------------------------------------------------------------------------------

# %% [markdown]
# EJERCICIO NUMERO 1
# LEY DE BOYLE

# %%
from drawdata import draw_scatter, draw_histogram, draw_line
draw_scatter()
#P vs V
# Out:
#         <iframe
#             width="800"
#             height="550"
#             src="https://drawdata.xyz/scatter.html"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %% [markdown]
# ![1.1.PNG](data:image/png;base64,...)

# %%
boyle = pd.read_csv("boyle.csv")
boyle
#presion y, volumen x
# Out:
#               x           y  z
# 0     83.395773  406.974398  a
# 1     66.326312  435.621408  a
# 2     47.027617  410.822258  a
# 3     60.319162  467.119411  a
# 4     54.007263  377.190202  a
# ..          ...         ... ..
# 356  462.219336  139.763430  a
# 357  433.888133   82.223509  a
# 358  443.854180  138.545858  a
# 359  448.173516  156.010115  a
# 360  453.126562  133.271298  a
#
# [361 rows x 3 columns]

# %%
plt.scatter(1/boyle["x"],boyle["y"])

# %%
def RegLin (LX, LY):
  sumX = 0
  sumY = 0
  sumXY = 0
  sumXcuadrado = 0
  for elemento in LX:
    sumX += elemento
    sumXcuadrado = elemento**2
  for elemento in LY:
    sumY += elemento
  i = 0
  for elemento in LX:
    sumXY = LX[i]*LY[i]
    i+=1
  p = i

  m = (((p*sumXY)-(sumX*sumY))/((p*sumXcuadrado)-(sumX*sumX)))
  b = (((sumXcuadrado*sumY)-(sumX*sumXY))/((p*sumXcuadrado)-(sumX*sumX)))
  return f"{round(m,1)}x + {round(b,1)}"
print("p =", RegLin(boyle["x"], boyle["y"]))
# Out:
# p = 1.1x + -2.1

# %% [markdown]
# --------------------------------------------------------------------------------

# %% [markdown]
# EJERCICIO NUMERO 1  LEY DE CHARLES

# %%
from drawdata import draw_scatter, draw_histogram, draw_line
draw_scatter()
#V vs T
# Out:
#         <iframe
#             width="800"
#             height="550"
#             src="https://drawdata.xyz/scatter.html"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %% [markdown]
# ![1.2.PNG](data:image/png;base64,...)

# %%
charles = pd.read_csv("charles.csv")
charles
# Out:
#               x           y  z
# 0      7.672123   21.332959  a
# 1     95.193409   48.639420  a
# 2     18.782295  106.091617  a
# 3     49.942297   65.806744  a
# 4     77.996532    9.566366  a
# ..          ...         ... ..
# 172  435.203311  379.969746  a
# 173  431.401199  360.733746  a
# 174  432.267633  385.681054  a
# 175  459.356699  418.573147  a
# 176  462.174136  355.584491  a
#
# [177 rows x 3 columns]

# %%
def RegLin (LX, LY):
  sumX = 0
  sumY = 0
  sumXY = 0
  sumXcuadrado = 0
  for elemento in LX:
    sumX += elemento
    sumXcuadrado = elemento**2
  for elemento in LY:
    sumY += elemento
  i = 0
  for elemento in LX:
    sumXY = LX[i]*LY[i]
    i+=1
  p = i

  m = (((p*sumXY)-(sumX*sumY))/((p*sumXcuadrado)-(sumX*sumX)))
  b = (((sumXcuadrado*sumY)-(sumX*sumXY))/((p*sumXcuadrado)-(sumX*sumX)))
  return f"{round(m,1)}x + {round(b,1)}"
print("p =", RegLin(charles["x"], charles["y"]))
# Out:
# p = 0.8x + -0.4

# %% [markdown]
# --------------------------------------------------------------------------------

# %% [markdown]
#  EJERCICIO NUMERO 1  GAY LUSACC

# %%
from drawdata import draw_scatter, draw_histogram, draw_line
draw_scatter()
#P vs T
# Out:
#         <iframe
#             width="800"
#             height="550"
#             src="https://drawdata.xyz/scatter.html"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %% [markdown]
# ![1.3.PNG](data:image/png;base64,...)

# %%
lusac = pd.read_csv("lussac.csv")
lusac
# Out:
#               x           y  z
# 0      4.359045   16.102515  a
# 1     -3.882643   34.009837  a
# 2      9.984828   52.398399  a
# 3     35.712352   52.205973  a
# 4     34.591927   44.879020  a
# ..          ...         ... ..
# 162  380.414775  378.012700  a
# 163  473.554576  405.616671  a
# 164  438.991037  383.806029  a
# 165  381.871813  396.595340  a
# 166  395.765163  421.920829  a
#
# [167 rows x 3 columns]

# %%
def RegLin (LX, LY):
  sumX = 0
  sumY = 0
  sumXY = 0
  sumXcuadrado = 0
  for elemento in LX:
    sumX += elemento
    sumXcuadrado = elemento**2
  for elemento in LY:
    sumY += elemento
  i = 0
  for elemento in LX:
    sumXY = LX[i]*LY[i]
    i+=1
  p = i

  m = (((p*sumXY)-(sumX*sumY))/((p*sumXcuadrado)-(sumX*sumX)))
  b = (((sumXcuadrado*sumY)-(sumX*sumXY))/((p*sumXcuadrado)-(sumX*sumX)))
  return f"{round(m,1)}x + {round(b,1)}"
print("p =", RegLin(lusac["x"], lusac["y"]))
# Out:
# p = 1.0x + 0.5

# %% [markdown]
# --------------------------------------------------------------------------------

# %% [markdown]
# EJERCICIO 1 NUMERO DE MOLÉCULAS vs VELOCIDAD

# %% [markdown]
# ![boltz_maxw.PNG](data:image/png;base64,...)

# %% [markdown]
# de la imagen a) :

# %%
draw_histogram()
# Out:
#         <iframe
#             width="800"
#             height="550"
#             src="https://drawdata.xyz/histogram.html"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %% [markdown]
# ![1.4a.PNG](data:image/png;base64,...)

# %%
imga = pd.read_csv("imga.csv")
imga
# Out:
#          x      y  z
# 0    0.000  0.000  a
# 1    0.025  0.064  a
# 2    0.050  0.162  a
# 3    0.075  0.268  a
# 4    0.100  0.362  a
# ..     ...    ... ..
# 115  0.875  0.044  c
# 116  0.900  0.036  c
# 117  0.925  0.030  c
# 118  0.950  0.002  c
# 119  0.975  0.000  c
#
# [120 rows x 3 columns]

# %%
plt.plot(imga["x"],imga["y"])

# %% [markdown]
# de la imagen b) :

# %%
draw_histogram()
# Out:
#         <iframe
#             width="800"
#             height="550"
#             src="https://drawdata.xyz/histogram.html"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %% [markdown]
# ![1.4b.PNG](data:image/png;base64,...)

# %%
imgb = pd.read_csv("imgb.csv")
imgb
# Out:
#          x      y  z
# 0    0.000  0.090  a
# 1    0.025  0.518  a
# 2    0.050  0.698  a
# 3    0.075  0.886  a
# 4    0.100  0.780  a
# ..     ...    ... ..
# 115  0.875 -0.002  c
# 116  0.900  0.000  c
# 117  0.925 -0.004  c
# 118  0.950 -0.002  c
# 119  0.975 -0.006  c
#
# [120 rows x 3 columns]

# %%
plt.plot(imgb["x"],imgb["y"])

# %% [markdown]
# --------------------------------------------------------------------------------

# %% [markdown]
# EJERCICIO 2: EXTRAER PROPIEDADES DE LOS GASES Y HACER UN ANÁLISIS GRÁFICO Y ESTADÍSTICO

# %%
url = "https://es.wikipedia.org/wiki/Gas_de_efecto_invernadero"
tabla = pd.read_html(url)
tabla[1]
# Out:
#              Nombre del gas Fórmula química Años de vida  \
#              Nombre del gas Fórmula química Años de vida
# 0        Dióxido de carbono             CO2        30–95
# 1                    Metano             CH4           12
# 2             Óxido nitroso             N2O          121
# 3     Diclorodifluorometano          CCl2F2          100
# 4       Clorodifluorometano          CHClF2           12
# 5         Tetrafluorometano             CF4       50 000
# 6            Hexafluoretano            C2F6       10 000
# 7    Hexafluoruro de azufre             SF6        3 200
# 8  Trifluoruro de nitrógeno             NF3          500
#
#   Potencial de calentamiento global (PCA) para un tiempo determinado           \
#                                                              20 años 100 años
# 0                                                  1                        1
# 1                                                 84                       28
# ...

# %%
#tenemos en cuenta que PCA = potencial de calentamiento global
tabla[1]["Fórmula química"]
# Out:
#   20 años 100 años 500 años
# 0       1        1        1
# 1      84       28      7.6
# 2     264      265      153
# 3  10 800   10 200    5 200
# 4   5 280    1 760      549
# 5   4 880    6 630   11 200
# 6   8 210   11 100   18 200
# 7  17 500   23 500   32 600
# 8  12 800   16 100   20 700

# %%
tabla[1]["Potencial de calentamiento global (PCA) para un tiempo determinado"]
# Out:
#   20 años 100 años 500 años
# 0       1        1        1
# 1      84       28      7.6
# 2     264      265      153
# 3  10 800   10 200    5 200
# 4   5 280    1 760      549
# 5   4 880    6 630   11 200
# 6   8 210   11 100   18 200
# 7  17 500   23 500   32 600
# 8  12 800   16 100   20 700

# %%
FormulaQuimica = ["CO2","CH4","N2O","CCl2F2","CHClF2","CF4","C2F6","SF6","NF3"]
PCA = [1,84,264,10800,5280,4880,8210,17500,12800]
plt.bar(FormulaQuimica,PCA)

plt.show()

# %%
formulas = ["CO2","CH4","N2O","CCl2F2","CHClF2","CF4","C2F6","SF6","NF3"]
PCA = [1,84,264,10800,5280,4880,8210,17500,12800]

plt.pie(PCA, labels = formulas);
#este diagrama circular es referencial de los compuestos respecto a su PCA
